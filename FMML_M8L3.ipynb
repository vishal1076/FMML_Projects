# %% [markdown]
# <a href="https://colab.research.google.com/github/vishal1076/FMML_Projects/blob/main/FMML_M8L3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2025-04-22 10:23:43--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json’
#
# arxiv-paper-data.js 100%[===================>]  69.07M  89.2MB/s    in 0.8s
#
# 2025-04-22 10:23:44 (89.2 MB/s) - ‘arxiv-paper-data.json’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 3500 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 2500 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 1  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 8  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False),
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split()
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 27700  1704.02930v2  We combine features extracted from pre-trained...    cs
# 7643   1802.06300v1  We extend conformal inference to general setti...  stat
# 11213  1501.07340v1  We analyze the problem of sequential probabili...    cs
# 12470  1802.04365v1  Open set recognition problems exist in many do...    cs
# 3520   1710.11052v1  Two of the most popular modelling paradigms in...  stat
# ...             ...                                                ...   ...
# 39283  1507.08958v1  We present a system for complementing snow phe...    cs
# 7679   1802.07756v1  Motivation: Thanks to digitization, we often h...  stat
# 34955   1402.4007v1  Time perception is essential for task switchin...    cs
# 2423    1206.6862v1  Bayesian Networks (BNs) are useful tools givin...    cs
# 28418  1706.05791v1  This paper aims to simultaneously accelerate a...    cs
#
#                                                    title  year  \
# 27700  Fast Learning and Prediction for Object Detect...  2017
# 7643   Exact and Robust Conformal Inference Methods f...  2018
# 11213  Sequential Probability Assignment with Binary ...  2015
# 12470  Learning a Neural-network-based Representation...  2018
# 3520   A Connection between Feed-Forward Neural Netwo...  2017
# ...                                                  ...   ...
# 39283  SnowWatch: Snow Monitoring through Acquisition...  2015
# 7679   Determining the best classifier for predicting...  2018
# 34955  Does the D.C. Response of Memristors Allow Rob...  2014
# 2423   On the Number of Samples Needed to Learn the C...  2012
# 28418  An Entropy-based Pruning Method for CNN Compre...  2017
#
#                                                 keywords
# 27700  [extracted, convolutional, classifier, advanta...
# 7643   [conformal, inference, developed, randomizatio...
# 11213  [sequential, probability, assignment, informat...
# 12470  [recognition, regularly, therefore, classifica...
# 3520   [modelling, paradigms, probabilistic, graphica...
# ...                                                  ...
# 39283  [complementing, phenomena, monitoring, measure...
# 7679   [motivation, digitization, databases, consisti...
# 34955  [perception, essential, switching, mammalian, ...
# 2423   [representation, probability, distributions, a...
# 28418  [simultaneously, accelerate, importance, evalu...
#
# [4800 rows x 6 columns]

# %%
df['keywords']
# Out:
# 27700    [extracted, convolutional, classifier, advanta...
# 7643     [conformal, inference, developed, randomizatio...
# 11213    [sequential, probability, assignment, informat...
# 12470    [recognition, regularly, therefore, classifica...
# 3520     [modelling, paradigms, probabilistic, graphica...
#                                ...
# 11052    [factorization, archetypal, approximated, arch...
# 24389    [community, explosion, sophisticated, detectio...
# 11720    [increasingly, solutions, characteristic, info...
# 32390    [supervised, classifiers, constructed, informa...
# 15472    [supervised, sentences, crosslingual, delexica...
# Name: keywords, Length: 6000, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]),
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 8836 words.
# Out of those 4621 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="f6accbbc-3d87-49f6-aa6f-06e914b479cb" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f6accbbc-3d87-49f6-aa6f-06e914b479cb")) {                    Plotly.newPlot(                        "f6accbbc-3d87-49f6-aa6f-06e914b479cb",                        [{"x":["convolutional","extracted","performance","prediction","detection","classifier","automatic","combination","advantages","engineering","efficient","experimental","including","conformity","exchangeable","dependence","exchangeability","permutation","predictive","dependent","structures","potential","conformal","approximately","generally","developed","randomization","inference","assumptions","probability","independent","sridharan","introduced","redundancy","complexities","techniques","bernstein","dimensional","concordant","lipschitz","algorithm","logarithmic","regularization","information","gradients","functions","assignment","unbounded","intrinsic","sequential","technique","discretization","alphabets","parametrized","illustrated","euclidean","addressing","regularly","significant","instances","resulting","recognition","different","approaches","discriminating","classification","representation","improvement","therefore","statistically","observation","graphical","essentially","connections","implements","expressing","connection","approximation","characterize","generalization","counterparts","corresponding","establishes","particular","segmentation","capability","paradigms","modelling","probabilistic","consistency","unspecified","qualitative","directional","direction","incomplete","tractable","directions","intractable","subclasses","expressive","reduction","reasoning","constraints","connecting","embedding","competitive","combinatorial","comprehensive","translation","relations","relational","knowledge","understanding","effectiveness","predicate","relationship","extraction","challenging","complexity","demonstrate","production","describes","computational","collected","naturally","descriptions","transcribed","linguistic","sentences","benchmarking","precisely","according","interesting","description","temporally","comparing","linguistics","descriptive","generating","discovery","contemporary","especially","postulate","restrictive","procedure","implement","nonparametric","synthetic","extensive","estimator","relationships","kolmogorov","observational","independence","favorably","distribution","bivariate","mechanism","conditional","computationally","applications","regularizing","differentiable","computation","incorporate","regularized","approximations","efficiently","theoretical","completely","transport","unconstrained","formulations","optimization","corresponds","problematic","regularizations","unregularized","transportation","framework","parameters","variationally","posteriors","simultaneously","available","likelihood","processes","variational","covariance","approximate","considerable","posterior","computations","experiment","parameter","attacking","replicate","otherwise","addresses","appealing"],"y":[377,114,876,222,341,148,178,123,93,55,421,385,251,1,0,30,1,13,60,74,124,146,1,35,74,194,6,207,65,185,152,1,127,22,9,374,4,214,1,8,847,21,82,705,30,218,33,12,48,69,251,7,6,8,20,31,29,4,267,102,157,384,762,426,10,502,365,138,140,20,64,62,27,47,16,10,34,132,48,113,18,136,11,266,210,55,9,58,170,55,2,59,14,52,38,33,48,21,3,35,114,141,138,15,118,115,44,67,97,84,25,354,169,212,7,71,134,280,222,568,19,101,287,75,69,32,3,64,72,13,28,113,69,58,18,88,9,15,99,56,16,119,2,11,121,75,19,133,173,25,60,3,11,38,18,220,1,117,101,89,427,4,24,176,64,37,42,145,149,31,14,20,12,347,17,10,4,2,14,549,234,1,4,122,293,55,96,55,24,125,36,36,36,92,107,6,2,15,59,16],"type":"bar"},{"x":["convolutional","extracted","perfor ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (4621,), (4621, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.8175

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>The</span> <span style=''>Helsinki</span> <span style=''>Neural</span> <span style=''>Machine</span> <span style='background-color:rgba(0, 255, 0, 0.8130841121495327);'>Translation</span> <span style=''>System</span> <br/><br/><span style=''>We</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>introduce</span> <span style=''>the</span> <span style=''>Helsinki</span> <span style=''>Neural</span> <span style=''>Machine</span> <span style='background-color:rgba(0, 255, 0, 0.8130841121495327);'>Translation</span> <span style=''>system</span> <span style=''>(HNMT)</span> <span style=''>and</span> <span style=''>how</span> <span style=''>it</span> <span style=''>is</span> <span style=''>applied</span> <span style=''>in</span> <span style=''>the</span> <span style=''>news</span> <span style='background-color:rgba(0, 255, 0, 0.8130841121495327);'>translation</span> <span style=''>task</span> <span style=''>at</span> <span style=''>WMT</span> <span style=''>2017</span> <span style=''>where</span> <span style=''>it</span> <span style=''>ranked</span> <span style=''>first</span> <span style=''>in</span> <span style=''>both</span> <span style=''>the</span> <span style=''>human</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.5213675213675213);'>automatic</span> <span style='background-color:rgba(0, 255, 0, 0.3707865168539326);'>evaluations</span> <span style=''>for</span> <span style=''>English</span> <span style=''>Finnish</span> <span style=''>We</span> <span style=''>discuss</span> <span style=''>the</span> <span style=''>success</span> <span style=''>of</span> <span style=''>English</span> <span style=''>Finnish</span> <span style='background-color:rgba(0, 255, 0, 1.0);'>translations</span> <span style=''>and</span> <span style=''>the</span> <span style=''>overall</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>advantage</span> <span style=''>of</span> <span style=''>NMT</span> <span style=''>over</span> <span style=''>a</span> <span style=''>strong</span> <span style=''>SMT</span> <span style=''>baseline</span> <span style=''>We</span> <span style=''>also</span> <span style=''>discuss</span> <span style=''>our</span> <span style='background-color:rgba(0, 255, 0, 0.5999999999999999);'>submissions</span> <span style=''>for</span> <span style=''>English</span> <span style=''>Latvian</span> <span style=''>English</span> <span style=''>Chinese</span> <span style=''>and</span> <span style=''>Chinese</span> <span style=''>English</span> <br/><br/>

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(0, 255, 0, 0.3);'>Variational</span> <span style=''>Bayes</span> <span style=''>approach</span> <span style=''>for</span> <span style=''>model</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>aggregation</span> <span style=''>in</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>unsupervised</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>classification</span> <span style=''>with</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Markovian</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>dependency</span> <br/><br/><span style=''>We</span> <span style=''>consider</span> <span style=''>a</span> <span style=''>binary</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>unsupervised</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>classification</span> <span style=''>problem</span> <span style=''>where</span> <span style=''>each</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>observation</span> <span style=''>is</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>associated</span> <span style=''>with</span> <span style=''>an</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>unobserved</span> <span style=''>label</span> <span style=''>that</span> <span style=''>we</span> <span style=''>want</span> <span style=''>to</span> <span style=''>retrieve</span> <span style=''>More</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>precisely</span> <span style=''>we</span> <span style=''>assume</span> <span style=''>that</span> <span style=''>there</span> <span style=''>are</span> <span style=''>two</span> <span style=''>groups</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>observation</span> <span style=''>normal</span> <span style=''>and</span> <span style=''>abnormal</span> <span style=''>The</span> <span style=''>normal</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>observations</span> <span style=''>are</span> <span style=''>coming</span> <span style=''>from</span> <span style=''>a</span> <span style=''>known</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>distribution</span> <span style=''>whereas</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>distribution</span> <span style=''>of</span> <span style=''>the</span> <span style=''>abnormal</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>observations</span> <span style=''>is</span> <span style=''>unknown</span> <span style=''>Several</span> <span style=''>models</span> <span style=''>have</span> <span style=''>been</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>developed</span> <span style=''>to</span> <span style=''>fit</span> <span style=''>this</span> <span style=''>unknown</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>distribution</span> <span style=''>In</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>we</span> <span style=''>propose</span> <span style=''>an</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>alternative</span> <span style=''>based</span> <span style=''>on</span> <span style=''>a</span> <span style=''>mixture</span> <span style=''>of</span> <span style=''>Gaussian</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>distributions</span> <span style=''>The</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>inference</span> <span style=''>is</span> <span style=''>done</span> <span style=''>within</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>variational</span> <span style=''>Bayesian</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>framework</span> <span style=''>and</span> <span style=''>our</span> <span style=''>aim</span> <span style=''>is</span> <span style=''>to</span> <span style=''>infer</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>posterior< ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>The</span> <span style=''>Scaling</span> <span style=''>Limit</span> <span style=''>of</span> <span style=''>High</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Dimensional</span> <span style=''>Online</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Independent</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Component</span> <span style=''>Analysis</span> <br/><br/><span style=''>We</span> <span style=''>analyze</span> <span style=''>the</span> <span style=''>dynamics</span> <span style=''>of</span> <span style=''>an</span> <span style=''>online</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithm</span> <span style=''>for</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>independent</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>component</span> <span style=''>analysis</span> <span style=''>in</span> <span style=''>the</span> <span style=''>high</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>dimensional</span> <span style=''>scaling</span> <span style=''>limit</span> <span style=''>As</span> <span style=''>the</span> <span style=''>ambient</span> <span style='background-color:rgba(255, 0, 0, 0.34358974358974365);'>dimension</span> <span style=''>tends</span> <span style=''>to</span> <span style=''>infinity</span> <span style=''>and</span> <span style=''>with</span> <span style=''>proper</span> <span style=''>time</span> <span style=''>scaling</span> <span style=''>we</span> <span style=''>show</span> <span style=''>that</span> <span style=''>the</span> <span style=''>time</span> <span style=''>varying</span> <span style=''>joint</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>empirical</span> <span style=''>measure</span> <span style=''>of</span> <span style=''>the</span> <span style=''>target</span> <span style=''>feature</span> <span style=''>vector</span> <span style=''>and</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>estimates</span> <span style=''>provided</span> <span style=''>by</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithm</span> <span style=''>will</span> <span style=''>converge</span> <span style=''>weakly</span> <span style=''>to</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>deterministic</span> <span style=''>measured</span> <span style=''>valued</span> <span style=''>process</span> <span style=''>that</span> <span style=''>can</span> <span style=''>be</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>characterized</span> <span style=''>as</span> <span style=''>the</span> <span style=''>unique</span> <span style=''>solution</span> <span style=''>of</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.4011299435028248);'>nonlinear</span> <span style=''>PDE</span> <span style='background-color:rgba(255, 0, 0, 0.44027303754266217);'>Numerical</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>solutions</span> <span style=''>of</span> <span style=''>this</span> <span style=''>PDE</span> <span style=''>which</span> <span style=''>involves</span> <span style=''>two</span> <span style=''>spatial</span> <span style='background-color:rgba(255, 0, 0, 0.45803357314148685);'>variables</span> <span style=''>and</span> <span style=''>one</span> <span style=''>time</span> <span style=''>variable</span> <span style=''>can</span> <span style=''>be</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>efficiently</span> <span style=''>obtained</span> <span style=''>These</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>solutions</span> <span style=''>provide</span> <span style=''>detailed</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>information</span> <span style=''>about</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>performance</span> <span style=''>of</span> <span style=''> ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>L1</span> <span style=''>norm</span> <span style=''>Kernel</span> <span style=''>PCA</span> <br/><br/><span style=''>We</span> <span style=''>present</span> <span style=''>the</span> <span style=''>first</span> <span style=''>model</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithm</span> <span style=''>for</span> <span style=''>L1</span> <span style=''>norm</span> <span style=''>kernel</span> <span style=''>PCA</span> <span style=''>While</span> <span style=''>L2</span> <span style=''>norm</span> <span style=''>kernel</span> <span style=''>PCA</span> <span style=''>has</span> <span style=''>been</span> <span style=''>widely</span> <span style=''>studied</span> <span style=''>there</span> <span style=''>has</span> <span style=''>been</span> <span style=''>no</span> <span style=''>work</span> <span style=''>on</span> <span style=''>L1</span> <span style=''>norm</span> <span style=''>kernel</span> <span style=''>PCA</span> <span style=''>For</span> <span style=''>this</span> <span style=''>non</span> <span style=''>convex</span> <span style=''>and</span> <span style=''>non</span> <span style=''>smooth</span> <span style=''>problem</span> <span style=''>we</span> <span style=''>offer</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>geometric</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>understandings</span> <span style=''>through</span> <span style=''>reformulations</span> <span style=''>and</span> <span style=''>present</span> <span style=''>an</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>efficient</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithm</span> <span style=''>where</span> <span style=''>the</span> <span style=''>kernel</span> <span style=''>trick</span> <span style=''>is</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>applicable</span> <span style=''>To</span> <span style=''>attest</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>efficiency</span> <span style=''>of</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithm</span> <span style=''>we</span> <span style=''>provide</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>convergence</span> <span style=''>analysis</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>including</span> <span style=''>linear</span> <span style=''>rate</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>convergence</span> <span style=''>Moreover</span> <span style=''>we</span> <span style=''>prove</span> <span style=''>that</span> <span style=''>the</span> <span style=''>output</span> <span style=''>of</span> <span style=''>our</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithm</span> <span style=''>is</span> <span style=''>a</span> <span style=''>local</span> <span style=''>optimal</span> <span style=''>solution</span> <span style=''>to</span> <span style=''>the</span> <span style=''>L1</span> <span style=''>norm</span> <span style=''>kernel</span> <span style=''>PCA</span> <span style=''>problem</span> <span style=''>We</span> <span style=''>also</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>numerically</span> <span style=''>show</span> <span style=''>its</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>robustness</span> <span style=''>when</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>extracting</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>principal</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>components</span> <span style=''>in</span> <span style=''>the</span> <span style=''>presence</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>influential</span> <span style=''>outliers</span> <span style=''>as</span> <span style=''>well</span> <span style=''>as</span> <span style=''>its</span> <sp ...

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	challenging (0.10141253169141615)
# 	knowledge (0.1282144150670047)
# 	segmentation (0.07605939876856212)
# 	architecture (0.09090909090909091)
# 	experimental (0.1394422310756972)
# 	detection (0.12350597609561753)
# 	information (0.2553422672944585)
# 	different (0.27598696124592537)
# 	convolutional (0.13654473017022817)
# 	recognition (0.13908004346251357)
#
# Some Statistics words are:
# 	numerical (0.10348209906817067)
# 	distributions (0.11623344776851398)
# 	theoretical (0.14369789112309955)
# 	distribution (0.18097106424717999)
# 	estimation (0.17655713585090732)
# 	statistical (0.15890142226581658)
# 	variables (0.14909269249632173)
# 	inference (0.1902893575282001)
# 	dimensional (0.19323197645904855)
# 	regression (0.18489455615497793)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]),
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="efa9fc7e-0c0b-4543-9431-89a80a443777" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("efa9fc7e-0c0b-4543-9431-89a80a443777")) {                    Plotly.newPlot(                        "efa9fc7e-0c0b-4543-9431-89a80a443777",                        [{"x":["convolutional","extracted","performance","prediction","detection","classifier","automatic","combination","advantages","engineering","efficient","experimental","including","conformity","exchangeable","dependence","exchangeability","permutation","predictive","dependent","structures","potential","conformal","approximately","generally","developed","randomization","inference","assumptions","probability","independent","sridharan","introduced","redundancy","complexities","techniques","bernstein","dimensional","concordant","lipschitz","algorithm","logarithmic","regularization","information","gradients","functions","assignment","unbounded","intrinsic","sequential","technique","discretization","alphabets","parametrized","illustrated","euclidean","addressing","regularly","significant","instances","resulting","recognition","different","approaches","discriminating","classification","representation","improvement","therefore","statistically","observation","graphical","essentially","connections","implements","expressing","connection","approximation","characterize","generalization","counterparts","corresponding","establishes","particular","segmentation","capability","paradigms","modelling","probabilistic","consistency","unspecified","qualitative","directional","direction","incomplete","tractable","directions","intractable","subclasses","expressive","reduction","reasoning","constraints","connecting","embedding","competitive","combinatorial","comprehensive","translation","relations","relational","knowledge","understanding","effectiveness","predicate","relationship","extraction","challenging","complexity","demonstrate","production","describes","computational","collected","naturally","descriptions","transcribed","linguistic","sentences","benchmarking","precisely","according","interesting","description","temporally","comparing","linguistics","descriptive","generating","discovery","contemporary","especially","postulate","restrictive","procedure","implement","nonparametric","synthetic","extensive","estimator","relationships","kolmogorov","observational","independence","favorably","distribution","bivariate","mechanism","conditional","computationally","applications","regularizing","differentiable","computation","incorporate","regularized","approximations","efficiently","theoretical","completely","transport","unconstrained","formulations","optimization","corresponds","problematic","regularizations","unregularized","transportation","framework","parameters","variationally","posteriors","simultaneously","available","likelihood","processes","variational","covariance","approximate","considerable","posterior","computations","experiment","parameter","attacking","replicate","otherwise","addresses","appealing","classifiers","represents","associate","estimated","experiments","predictions","incorporating","sequentially","criterion","maximizing","outperforms","alleviate","coefficient","estimation","considers","coefficients","selection","following","significance","contribution","measurements","evaluated","supervised","performances","parametric","application","perspectives","considered","regression","maintenance","spectroscopy","variables","imaginary","feasibility","extracting","celebrities","effective","aggregate","maximizes","illumination","explicitly","correlations","statistical","attention","development","benchmarks","weighting","integrated","generalized","variations","discrepancy","minimizes","resoluti ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	exchangeable
# 	lindenstrauss
# 	certifiable
# 	radiographs
# 	proportionality
# 	epidemics
# 	psychiatry
# 	independencies
# 	penalization
# 	incidence
# 	physician
# 	transplantation
# 	presupposes
# 	reparameterizing
# 	invariably
# 	looseness
# 	spectroradiometer
# 	electricity
# 	expository
# 	thermostat
# Some words which never appear in Statistics papers:
# 	regularly
# 	transcribed
# 	celebrities
# 	illumination
# 	deformations
# 	interpersonal
# 	discourse
# 	fixations
# 	segmenter
# 	redefined
# 	transliteration
# 	underwater
# 	executions
# 	deliberately
# 	deceptive
# 	interdependent
# 	entailment
# 	paraphrase
# 	conversations
# 	multiphase

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 3.102603083987466e-05

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7716666666666666
